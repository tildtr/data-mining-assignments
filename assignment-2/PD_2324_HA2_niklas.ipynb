# %% [markdown]
# # Prospecção de Dados (Data Mining) DI/FCUL - HA2
#
# ## Second Home Assignement (MC/DI/FCUL - 2024)
#
# ### Fill in the section below
#
# ### GROUP:`13`
#
# * Miguel Landum, 35019 - Hours worked on the project
# * Niklas Schmitz, 62689 - Hours worked on the project
# * Pol Parra, 62692 - Hours worked on the project
# * Til Dietrich, 62928 - Hours worked on the project

# %% [markdown]
# ## Objectives
# The purpose of this Home Assignment is:
#
# 1. Analyze the itemset/rules generation procedure
# 2. Process and identify the most relevant rules
#
# **NOTE 1: Students are not allowed to add more cells to the notebook**
#
# **NOTE 2: The notebook must be submited fully executed**

# %% [markdown]
# ### 1. Read the Dataset
#
# Dataset: Instacart [Market Basket Analysis](https://www.kaggle.com/datasets/psparks/instacart-market-basket-analysis)
#
#
#
# The purpose of this Home Assignment is:
#
# 1. Analyze the itemset/rules generation procedure
# 2. Identify the most relevant rules
#
# Please download the HA files from this moodle folder and inspect it like this:
# **NOTE 1: Students are not allowed to add more cells to the notebook**
#
# **NOTE 2: The notebook must be submited fully executed**
#
# The dataset has been preprocessed with transactions as lists of integers. It is necessary a decoder to see the actual products bought together
#
# Uncompress the data set (zip file) which will produce 2 files:
# * `order_products.pickle` a Python pickle with all the trasactions
# * A `products.txt` - decoder table with all the data relative to each item

# %% [markdown]
# **Important:** As the order products pickle file is larger than 100MB and therefore can't be uploaded to git, it is necessary to have the pickle file locally in the data folder: assignment-2/data/order_products__local.pickle. This file is included in .gitignore

# %%
#Read product names and IDs
lines=open("data/products.txt", "rt", encoding="utf8").readlines()
products=[0]*len(lines)
for lin in lines[1:]:
    pid, pname, aid, did=lin.strip().split("\t")    
    products[int(pid)]=pname
    
#read transactions
import pickle
orders=pickle.load(open("data/order_products__local.pickle", "rb"))

#check names of products on transaction 2 (example):
print("Transaction 2 is", orders[2])
for prod in orders[2]: print("Code: %5d is product: %s" %(prod, products[prod]))
# Out:
# Transaction 2 is [33120, 28985, 9327, 45918, 30035, 17794, 40141, 1819, 43668]
# Code: 33120 is product: Organic Egg Whites
# Code: 28985 is product: Michigan Organic Kale
# Code:  9327 is product: Garlic Powder
# Code: 45918 is product: Coconut Butter
# Code: 30035 is product: Natural Sweetener
# Code: 17794 is product: Carrots
# Code: 40141 is product: Original Unflavored Gelatine Mix
# Code:  1819 is product: All Natural No Stir Creamy Almond Butter
# Code: 43668 is product: Classic Blend Cole Slaw

# %% [markdown]
# ### Objective 1 - Analyze the itemset/rules generation procedure
#
# 1. From the approaches used in classes make a performance analysis up to a threshold level of support
# 2. Define a good support threshold for analysis according to your computational capabilities

# %%
### Add supporting functions here
lines = open("data/products.txt", "rt", encoding="utf8").readlines()
products = {}

# Extract product names and store them in a dictionary
for lin in lines[1:]:
    pid, pname, aid, did = lin.strip().split("\t")
    products[int(pid)] = pname

# Read transactions from the pickle file
import pickle
orders = pickle.load(open("data/order_products__local.pickle", "rb"))

# Create a new dictionary to store transactions with product names
orders_with_names = {}

# Replace product codes with product names in each transaction
for transaction_id, product_codes in orders.items():
    # Replace product codes with product names
    product_names = [products[code] for code in product_codes]
    # Store the transaction with product names in the new dictionary
    orders_with_names[transaction_id] = product_names
    
#Transfom the dictionary into a list   
orders_with_names_list = list(orders_with_names.values())

# %%
### Add processing code here

#Since the dataset is two big we do a random sample
import random
subset_size = 100000
subset_orders_with_names_list = random.sample(orders_with_names_list, subset_size)

# Compute binary database (transactions X products)
import pandas as pd
from mlxtend.preprocessing import  TransactionEncoder
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(subset_orders_with_names_list).transform(subset_orders_with_names_list)
binary_database = pd.DataFrame(trans_array, columns=tr_enc.columns_)

#Apriori, FP-Growth, and Eclat algorithms used for association rule mining in data mining 
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
from pyfim import pyeclat


import time

D={"threshold": [0.7, 0.2, 0.1, 0.05, 0.02, 0.01], 
   "num_itemsets":[],
   "apriori":[], 
   "FP-growth":[], 
   "ECLAT":[]}


for min_supp in D["threshold"]:
    t0 = time.time()
    FI_apriori=apriori(binary_database, min_supp)
    t1 = time.time()
    D["num_itemsets"].append(FI_apriori.shape[0])
    D["apriori"].append(t1-t0)

    FI_fpg= fpgrowth(binary_database, min_supp)
    t2 = time.time()
    D["FP-growth"].append(t2-t1)

    FI_eclat= pyeclat(subset_orders_with_names_list, min_supp)    
    t3 = time.time()
    D["ECLAT"].append(t3-t2) 

df_performance=pd.DataFrame(D)


# Generate frequent itemsets
FI_fpg = fpgrowth(binary_database, 0.01, use_colnames=True)
FI_eclat = pyeclat(subset_orders_with_names_list, 0.01) 
FI_apriori = apriori(binary_database, 0.01, use_colnames=True)  

FI_fpg['Algorithm'] = 'FP-Growth'
FI_fpg['Support'] = 0.01
FI_eclat['Algorithm'] = 'ECLAT'
FI_eclat['Support'] = 0.01
FI_apriori['Algorithm'] = 'Apriori'  
FI_apriori['Support'] = 0.01

combined_df = pd.concat([FI_fpg, FI_eclat, FI_apriori])

combined_df.reset_index(drop=True, inplace=True)


import matplotlib.pyplot as plt
plt.plot(df_performance["threshold"], df_performance["apriori"], label="Apriori")
plt.plot(df_performance["threshold"], df_performance["FP-growth"], label="FP-growth")
plt.plot(df_performance["threshold"], df_performance["ECLAT"], label="ECLAT")
plt.legend()
plt.xlabel('Threshold')
plt.ylabel('Performance Time (seconds)')
plt.show()



print(combined_df.to_string())

df_performance
# Out:
# /Users/niklas/miniconda3/lib/python3.11/site-packages/pyparsing.py:108: DeprecationWarning: module 'sre_constants' is deprecated
#   import sre_constants
#      support                                                           itemsets  Algorithm  Support
# 0      0.045                                                     (Strawberries)  FP-Growth     0.01
# 1      0.014                                         (Organic Reduced Fat Milk)  FP-Growth     0.01
# 2      0.010                                                  (Red Raspberries)  FP-Growth     0.01
# 3      0.134                                           (Bag of Organic Bananas)  FP-Growth     0.01
# 4      0.040                                               (Organic Fuji Apple)  FP-Growth     0.01
# 5      0.015                                            (Organic D'Anjou Pears)  FP-Growth     0.01
# 6      0.028                                              (Seedless Red Grapes)  FP-Growth     0.01
# 7      0.011                                                 (Fridge Pack Cola)  FP-Growth     0.01
# 8      0.013                                (Vanilla Almond Breeze Almond Milk)  FP-Growth     0.01
# 9      0.130                                                           (Banana)  FP-Growth     0.01
# 142    0.010                                  (Chicken Breast Tenders Breaded,)      ECLAT     0.01
# 143    0.010                                            (Feta Cheese Crumbles,)      ECLAT     0.01
# 144    0.010                                                          (Garlic,)      ECLAT     0.01
# 145    0.010                                            (Ground Turkey Breast,)      ECLAT     0.01
# 146    0.010                                                (Jalapeno Peppers,)      ECLAT     0.01
# 147    0.010                                       (No Salt Added Black Beans,)      ECLAT     0.01
# 148    0.010                                             (Organic Bell Pepper,)      ECLAT     0.01
# 149    0.010                                            (Organic Medium Salsa,)      ECLAT     0.01
# 150    0.010                                             (Organic Roma Tomato,)      ECLAT     0.01
# 151    0.010                                        (Organic Spring Mix Salad,)      ECLAT     0.01
# 152    0.010                         (Organic Uncured Sliced Black Forest Ham,)      ECLAT     0.01
# 153    0.010                                                       (Red Onion,)      ECLAT     0.01
# 154    0.010                                                 (Red Raspberries,)      ECLAT     0.01
# 155    0.010                                           (Roasted Turkey Breast,)      ECLAT     0.01
# 156    0.011                                      (100% Recycled Paper Towels,)      ECLAT     0.01
# 157    0.011                                                (Bunched Cilantro,)      ECLAT     0.01
# 158    0.011                                                (Fridge Pack Cola,)      ECLAT     0.01
# 159    0.011                                 (Frozen Organic Wild Blueberries,)      ECLAT     0.01
# 160    0.011                                                    (Green Onions,)      ECLAT     0.01
# 161    0.011                                             (Organic Black Beans,)      ECLAT     0.01
# 162    0.011                                    (Organic Heavy Whipping Cream,)      ECLAT     0.01
# 163    0.011                                            (Pure Sparkling Water,)      ECLAT     0.01
# 164    0.011                                                     (Roma Tomato,)      ECLAT     0.01
# 165    0.011                                 (Sparkling Natural Mineral Water,)      ECLAT     0.01
# 166    0.011                                    (Sustainably Soft Bath Tissue,)      ECLAT     0.01
# 167    0.011                                    (Total 0% Nonfat Greek Yogurt,)      ECLAT     0.01
# 168    0.011                                                      (Whole Milk,)      ECLAT     0.01
# 169    0.012   ("Super Spinach! Baby Spinach, Baby Bok Choy, Sweet Baby Kale",)      ECLAT     0.01
# 170    0.012                                             (2% Reduced Fat Milk,)      ECLAT     0.01
# 171    0.012                                          (Extra Virgin Olive Oil,)      ECLAT     0.01
# 172    0.012                                             (Granny Smith Apples,)      ECLAT     0.01
# 173    0.012                                (Organic Grade A Large Brown Eggs,)      ECLAT     0.01
# 174    0.012                                      (Organic Hothouse Cucumbers,)      ECLAT     0.01
# 175    0.012                     (Organic Large Brown Grade AA Cage Free Eggs,)      ECLAT     0.01
# 176    0.012                                   (Organic Roasted Turkey Breast,)      ECLAT     0.01
# 177    0.012  (Organic Sticks Low Moisture Part Skim Mozzarella String Cheese,)      ECLAT     0.01
# 178    0.012                                              (Plain Greek Yogurt,)      ECLAT     0.01
# 179    0.012                                                    (Spring Water,)      ECLAT     0.01
# 180    0.013                                              ("Clementines, Bag",)      ECLAT     0.01
# 181    0.013                                                  (Bartlett Pears,)      ECLAT     0.01
# 182    0.013                               (Boneless Skinless Chicken Breasts,)      ECLAT     0.01
# 183    0.013                                      (Grape White/Green Seedless,)      ECLAT     0.01
# 184    0.013                                                     (Green Beans,)      ECLAT     0.01
# 185    0.013                                                   (Hass Avocados,)      ECLAT     0.01
# 186    0.013                                                (Large Grapefruit,)      ECLAT     0.01
# 187    0.013                                           (Organic Baby Broccoli,)      ECLAT     0.01
# 188    0.013                                          (Organic Garbanzo Beans,)      ECLAT     0.01
# 189    0.013                                      (Organic Granny Smith Apple,)      ECLAT     0.01
# 190    0.013                             (Peach Pear Flavored Sparkling Water,)      ECLAT     0.01
# 191    0.013                               (Vanilla Almond Breeze Almond Milk,)      ECLAT     0.01
# 192    0.014                                             (Large Alfresco Eggs,)      ECLAT     0.01
# 193    0.014                                        (Organic Broccoli Florets,)      ECLAT     0.01
# 194    0.014                                (Organic Lacinato (Dinosaur) Kale,)      ECLAT     0.01
# 195    0.014                                            (Organic Navel Orange,)      ECLAT     0.01
# 196    0.014                                        (Organic Reduced Fat Milk,)      ECLAT     0.01
# 197    0.014                                         (Organic Romaine Lettuce,)      ECLAT     0.01
# 198    0.014                                 (Organic Unsweetened Almond Milk,)      ECLAT     0.01
# 199    0.014                                           (Sparkling Lemon Water,)      ECLAT     0.01
# 200    0.014                                            (Uncured Genoa Salami,)      ECLAT     0.01
# 201    0.015                                                     (Blueberries,)      ECLAT     0.01
# 202    0.015                                               (Green Bell Pepper,)      ECLAT     0.01
# 203    0.015                                            (Lime Sparkling Water,)      ECLAT     0.01
# 204    0.015                                           (Organic D'Anjou Pears,)      ECLAT     0.01
# 205    0.015                                   (Organic Green Seedless Grapes,)      ECLAT     0.01
# 206    0.015                                             (Organic Half & Half,)      ECLAT     0.01
# 207    0.015                                           (Original Orange Juice,)      ECLAT     0.01
# 208    0.015                                                     (Red Peppers,)      ECLAT     0.01
# 209    0.015                                                            (Soda,)      ECLAT     0.01
# 210    0.016                                                 (Grated Parmesan,)      ECLAT     0.01
# 211    0.016                                            (Organic Blackberries,)      ECLAT     0.01
# 212    0.016                                            (Organic Carrot Bunch,)      ECLAT     0.01
# 213    0.016                                     (Organic Reduced Fat 2% Milk,)      ECLAT     0.01
# 214    0.016                                                     (Raspberries,)      ECLAT     0.01
# 215    0.017                                             (Organic Ginger Root,)      ECLAT     0.01
# 216    0.017                                     (Organic Whole String Cheese,)      ECLAT     0.01
# 217    0.017                                      (Sparkling Water Grapefruit,)      ECLAT     0.01
# 218    0.017                                          (Unsweetened Almondmilk,)      ECLAT     0.01
# 219    0.017                                                   (Yellow Onions,)      ECLAT     0.01
# 220    0.018                                              (Orange Bell Pepper,)      ECLAT     0.01
# 221    0.018                                   (Organic Italian Parsley Bunch,)      ECLAT     0.01
# 222    0.018                                              (Small Hass Avocado,)      ECLAT     0.01
# 223    0.019                                          (100% Whole Wheat Bread,)      ECLAT     0.01
# 224    0.019                               (Organic Garnet Sweet Potato (Yam),)      ECLAT     0.01
# 225    0.020                                           (Michigan Organic Kale,)      ECLAT     0.01
# 226    0.020                                         (Organic Red Bell Pepper,)      ECLAT     0.01
# 227    0.021                                            (Organic Baby Arugula,)      ECLAT     0.01
# 228    0.021                                            (Organic Baby Carrots,)      ECLAT     0.01
# 229    0.021                                                (Organic Cilantro,)      ECLAT     0.01
# 230    0.022                                                     (Half & Half,)      ECLAT     0.01
# 231    0.022                                                (Organic Broccoli,)      ECLAT     0.01
# 232    0.022                                                   (Organic Lemon,)      ECLAT     0.01
# 233    0.023                                                         (Carrots,)      ECLAT     0.01
# 234    0.012                             (Organic Kiwi, Bag of Organic Bananas)      ECLAT     0.01
# 235    0.023                                                    (Organic Kiwi,)      ECLAT     0.01
# 236    0.023                            (Organic Large Extra Fancy Fuji Apple,)      ECLAT     0.01
# 237    0.023                                                 (Red Vine Tomato,)      ECLAT     0.01
# 238    0.010                 (Apple Honeycrisp Organic, Bag of Organic Bananas)      ECLAT     0.01
# 239    0.024                                        (Apple Honeycrisp Organic,)      ECLAT     0.01
# 240    0.024                                                       (Asparagus,)      ECLAT     0.01
# 241    0.024                                                (Honeycrisp Apple,)      ECLAT     0.01
# 242    0.024                                               (Organic Red Onion,)      ECLAT     0.01
# 243    0.024                                                 (Original Hummus,)      ECLAT     0.01
# 244    0.025                               (Organic Peeled Whole Baby Carrots,)      ECLAT     0.01
# 245    0.010                           (Organic Cucumber, Organic Baby Spinach)      ECLAT     0.01
# 246    0.026                                                (Organic Cucumber,)      ECLAT     0.01
# 247    0.026                                          (Organic Grape Tomatoes,)      ECLAT     0.01
# 248    0.026                                      (Organic Small Bunch Celery,)      ECLAT     0.01
# 249    0.026                                          (Organic Tomato Cluster,)      ECLAT     0.01
# 250    0.027                                                  (Cucumber Kirby,)      ECLAT     0.01
# 251    0.028                                             (Seedless Red Grapes,)      ECLAT     0.01
# 252    0.030                                             (Organic Gala Apples,)      ECLAT     0.01
# 253    0.032                                                  (Organic Garlic,)      ECLAT     0.01
# 254    0.033                                               (Fresh Cauliflower,)      ECLAT     0.01
# 255    0.010                        (Organic Blueberries, Organic Strawberries)      ECLAT     0.01
# 256    0.034                                             (Organic Blueberries,)      ECLAT     0.01
# 257    0.038                                                (Organic Zucchini,)      ECLAT     0.01
# 258    0.039                                            (Organic Yellow Onion,)      ECLAT     0.01
# 259    0.017                                       (Organic Fuji Apple, Banana)      ECLAT     0.01
# 260    0.040                                              (Organic Fuji Apple,)      ECLAT     0.01
# 261    0.041                                                     (Large Lemon,)      ECLAT     0.01
# 262    0.010                         (Organic Whole Milk, Organic Strawberries)      ECLAT     0.01
# 263    0.011                       (Organic Whole Milk, Bag of Organic Bananas)      ECLAT     0.01
# 264    0.042                                              (Organic Whole Milk,)      ECLAT     0.01
# 265    0.012                        (Organic Raspberries, Organic Hass Avocado)      ECLAT     0.01
# 266    0.015                      (Organic Raspberries, Bag of Organic Bananas)      ECLAT     0.01
# 267    0.045                                             (Organic Raspberries,)      ECLAT     0.01
# 268    0.010                                             (Strawberries, Banana)      ECLAT     0.01
# 269    0.045                                                    (Strawberries,)      ECLAT     0.01
# 270    0.011                                    (Limes, Bag of Organic Bananas)      ECLAT     0.01
# 271    0.051                                                           (Limes,)      ECLAT     0.01
# 272    0.011                                          (Organic Avocado, Banana)      ECLAT     0.01
# 273    0.055                                                 (Organic Avocado,)      ECLAT     0.01
# 274    0.011                     (Organic Baby Spinach, Bag of Organic Bananas)      ECLAT     0.01
# 275    0.062                                            (Organic Baby Spinach,)      ECLAT     0.01
# 276    0.016                       (Organic Hass Avocado, Organic Strawberries)      ECLAT     0.01
# 277    0.029                     (Organic Hass Avocado, Bag of Organic Bananas)      ECLAT     0.01
# 278    0.072                                            (Organic Hass Avocado,)      ECLAT     0.01
# 279    0.014                                     (Organic Strawberries, Banana)      ECLAT     0.01
# 280    0.020                     (Organic Strawberries, Bag of Organic Bananas)      ECLAT     0.01
# 281    0.083                                            (Organic Strawberries,)      ECLAT     0.01
# 282    0.130                                                          (Banana,)      ECLAT     0.01
# 283    0.134                                          (Bag of Organic Bananas,)      ECLAT     0.01
# 284    0.013                                               ("Clementines, Bag")    Apriori     0.01
# 285    0.012    ("Super Spinach! Baby Spinach, Baby Bok Choy, Sweet Baby Kale")    Apriori     0.01
# 286    0.011                                       (100% Recycled Paper Towels)    Apriori     0.01
# 287    0.019                                           (100% Whole Wheat Bread)    Apriori     0.01
# 288    0.012                                              (2% Reduced Fat Milk)    Apriori     0.01
# 289    0.024                                         (Apple Honeycrisp Organic)    Apriori     0.01
# 290    0.024                                                        (Asparagus)    Apriori     0.01
# 291    0.134                                           (Bag of Organic Bananas)    Apriori     0.01
# 292    0.130                                                           (Banana)    Apriori     0.01
# 293    0.013                                                   (Bartlett Pears)    Apriori     0.01
# 294    0.015                                                      (Blueberries)    Apriori     0.01
# 295    0.013                                (Boneless Skinless Chicken Breasts)    Apriori     0.01
# 296    0.011                                                 (Bunched Cilantro)    Apriori     0.01
# 297    0.023                                                          (Carrots)    Apriori     0.01
# 298    0.010                                   (Chicken Breast Tenders Breaded)    Apriori     0.01
# 299    0.027                                                   (Cucumber Kirby)    Apriori     0.01
# 300    0.012                                           (Extra Virgin Olive Oil)    Apriori     0.01
# 301    0.010                                             (Feta Cheese Crumbles)    Apriori     0.01
# 302    0.033                                                (Fresh Cauliflower)    Apriori     0.01
# 303    0.011                                                 (Fridge Pack Cola)    Apriori     0.01
# 304    0.011                                  (Frozen Organic Wild Blueberries)    Apriori     0.01
# 305    0.010                                                           (Garlic)    Apriori     0.01
# 306    0.012                                              (Granny Smith Apples)    Apriori     0.01
# 307    0.013                                       (Grape White/Green Seedless)    Apriori     0.01
# 308    0.016                                                  (Grated Parmesan)    Apriori     0.01
# 309    0.013                                                      (Green Beans)    Apriori     0.01
# 310    0.015                                                (Green Bell Pepper)    Apriori     0.01
# 311    0.011                                                     (Green Onions)    Apriori     0.01
# 312    0.010                                             (Ground Turkey Breast)    Apriori     0.01
# 313    0.022                                                      (Half & Half)    Apriori     0.01
# 314    0.013                                                    (Hass Avocados)    Apriori     0.01
# 315    0.024                                                 (Honeycrisp Apple)    Apriori     0.01
# 316    0.010                                                 (Jalapeno Peppers)    Apriori     0.01
# 317    0.014                                              (Large Alfresco Eggs)    Apriori     0.01
# 318    0.013                                                 (Large Grapefruit)    Apriori     0.01
# 319    0.041                                                      (Large Lemon)    Apriori     0.01
# 320    0.015                                             (Lime Sparkling Water)    Apriori     0.01
# 321    0.051                                                            (Limes)    Apriori     0.01
# 322    0.020                                            (Michigan Organic Kale)    Apriori     0.01
# 323    0.010                                        (No Salt Added Black Beans)    Apriori     0.01
# 371    0.026                                       (Organic Small Bunch Celery)    Apriori     0.01
# 372    0.010                                         (Organic Spring Mix Salad)    Apriori     0.01
# 373    0.012   (Organic Sticks Low Moisture Part Skim Mozzarella String Cheese)    Apriori     0.01
# 374    0.083                                             (Organic Strawberries)    Apriori     0.01
# 375    0.026                                           (Organic Tomato Cluster)    Apriori     0.01
# 376    0.010                          (Organic Uncured Sliced Black Forest Ham)    Apriori     0.01
# 377    0.014                                  (Organic Unsweetened Almond Milk)    Apriori     0.01
# 378    0.042                                               (Organic Whole Milk)    Apriori     0.01
# 379    0.017                                      (Organic Whole String Cheese)    Apriori     0.01
# 380    0.039                                             (Organic Yellow Onion)    Apriori     0.01
# 381    0.038                                                 (Organic Zucchini)    Apriori     0.01
# 382    0.024                                                  (Original Hummus)    Apriori     0.01
# 383    0.015                                            (Original Orange Juice)    Apriori     0.01
# 384    0.013                              (Peach Pear Flavored Sparkling Water)    Apriori     0.01
# 385    0.012                                               (Plain Greek Yogurt)    Apriori     0.01
# 386    0.011                                             (Pure Sparkling Water)    Apriori     0.01
# 387    0.016                                                      (Raspberries)    Apriori     0.01
# 388    0.010                                                        (Red Onion)    Apriori     0.01
# 389    0.015                                                      (Red Peppers)    Apriori     0.01
# 390    0.010                                                  (Red Raspberries)    Apriori     0.01
# 391    0.023                                                  (Red Vine Tomato)    Apriori     0.01
# 392    0.010                                            (Roasted Turkey Breast)    Apriori     0.01
# 393    0.011                                                      (Roma Tomato)    Apriori     0.01
# 394    0.028                                              (Seedless Red Grapes)    Apriori     0.01
# 395    0.018                                               (Small Hass Avocado)    Apriori     0.01
# 396    0.015                                                             (Soda)    Apriori     0.01
# 397    0.014                                            (Sparkling Lemon Water)    Apriori     0.01
# 398    0.011                                  (Sparkling Natural Mineral Water)    Apriori     0.01
# 399    0.017                                       (Sparkling Water Grapefruit)    Apriori     0.01
# 400    0.012                                                     (Spring Water)    Apriori     0.01
# 401    0.045                                                     (Strawberries)    Apriori     0.01
# 402    0.011                                     (Sustainably Soft Bath Tissue)    Apriori     0.01
# 403    0.011                                     (Total 0% Nonfat Greek Yogurt)    Apriori     0.01
# 404    0.014                                             (Uncured Genoa Salami)    Apriori     0.01
# 405    0.017                                           (Unsweetened Almondmilk)    Apriori     0.01
# 406    0.013                                (Vanilla Almond Breeze Almond Milk)    Apriori     0.01
# 407    0.011                                                       (Whole Milk)    Apriori     0.01
# 408    0.017                                                    (Yellow Onions)    Apriori     0.01
# 409    0.010                 (Bag of Organic Bananas, Apple Honeycrisp Organic)    Apriori     0.01
# 410    0.011                                    (Limes, Bag of Organic Bananas)    Apriori     0.01
# 411    0.011                     (Organic Baby Spinach, Bag of Organic Bananas)    Apriori     0.01
# 412    0.029                     (Bag of Organic Bananas, Organic Hass Avocado)    Apriori     0.01
# 413    0.012                             (Organic Kiwi, Bag of Organic Bananas)    Apriori     0.01
# 414    0.015                      (Bag of Organic Bananas, Organic Raspberries)    Apriori     0.01
# 415    0.020                     (Bag of Organic Bananas, Organic Strawberries)    Apriori     0.01
# 416    0.011                       (Organic Whole Milk, Bag of Organic Bananas)    Apriori     0.01
# 417    0.011                                          (Organic Avocado, Banana)    Apriori     0.01
# 418    0.017                                       (Organic Fuji Apple, Banana)    Apriori     0.01
# 419    0.014                                     (Banana, Organic Strawberries)    Apriori     0.01
# 420    0.010                                             (Banana, Strawberries)    Apriori     0.01
# 421    0.010                           (Organic Baby Spinach, Organic Cucumber)    Apriori     0.01
# 422    0.010                        (Organic Blueberries, Organic Strawberries)    Apriori     0.01
# 423    0.012                        (Organic Raspberries, Organic Hass Avocado)    Apriori     0.01
# 424    0.016                       (Organic Strawberries, Organic Hass Avocado)    Apriori     0.01
# 425    0.010                         (Organic Whole Milk, Organic Strawberries)    Apriori     0.01
#    threshold  num_itemsets   apriori  FP-growth     ECLAT
# 0       0.70             0  0.005975   0.007546  0.008025
# 1       0.20             0  0.005636   0.007721  0.006644
# 2       0.10             2  0.007697   0.008359  0.006521
# 3       0.05             7  0.005682   0.008943  0.006215
# 4       0.02            44  0.008946   0.009295  0.006858
# 5       0.01           142  0.031662   0.011806  0.009486

# %% [markdown]
# ### Your short analysis here
#
# The threshold column represents the minimum support threshold used in association rule mining. As the threshold decreases, more itemsets are considered frequent.
#
# The number of items column indicates the number of frequent itemsets generated by each algorithm at the corresponding threshold level. As expected, the number of itemsets generally increases as the threshold becomes less stringent, allowing for the inclusion of more itemsets in the analysis.
#
# Apriori's runtime increases significantly as the threshold decreases. This behavior is expected as Apriori's performance is influenced by the number of candidate itemsets generated, which tends to increase with lower support thresholds.
#
# FP-growth exhibits relatively consistent runtime across different threshold levels. This stability in runtime is one of the advantages of FP-growth over Apriori, as it does not rely on candidate generation and pruning steps.
#
# ECLAT's runtime decreases as the threshold becomes less stringent, which is somewhat counterintuitive but not uncommon. This behavior suggests that ECLAT may be more efficient at processing data with lower support thresholds, possibly due to its vertical data format and depth-first search approach.
#
# If the dataset size of the orders is increased probably at one point FP-Growth will perform better than ECLAT. In large datasets FP-Growth really shines as it is very scalable due to its compression of data into an FP-tree which generally requires less memory in comparison to the vertical dataset representation used by ECLAT.

# %% [markdown]
# ### Objective 2 - Identify the most relevant rules
#
# 1. From your predefined support level generate all available itemsets and generate rules
# 2. Identify a set of 10 relevant rules using the Highest Lift criterion
#     * **NOTE**: Present the rules with the product names and not as Integers
# 3. Identify the Maximal and Closed Itemsets for the same level of support and generate 5 rules using the Highest Lift
#     * **NOTE**: Do not list the Maximal or Closed Itemsets. Present just a few as an example and mention **how many** Closed and Maximal Itemsets were found for the selected support level
#     * **NOTE**: Present the rules with the product names and not as Integers

# %%
#Apriori, FP-Growth, and Eclat algorithms used for association rule mining in data mining 
from mlxtend.frequent_patterns import fpgrowth
from pyfim import pyeclat
from mlxtend.frequent_patterns import association_rules
from IPython.display import display, Markdown

FI_eclat = pyeclat(orders_with_names_list, supp=0.01)
print("Number itemsets: ", FI_eclat.shape[0])

# Running ECLAT to find maximal itemsets
maximal_itemsets = pyeclat(orders_with_names_list, target='m', supp=0.01)
print(maximal_itemsets)
print("Number of maximal itemsets: ", maximal_itemsets.shape[0])

# Running ECLAT to find closed itemsets
closed_itemsets = pyeclat(orders_with_names_list, target='c', supp=0.01)
print(closed_itemsets)
print("Number of closed itemsets: ", closed_itemsets.shape[0])

# Check overlap of maximal and closed itemsets
overlap = maximal_itemsets.isin(closed_itemsets)
print(f"Overlap between maximal and closed itemsets: {overlap.sum()}")
# Out:
# Number itemsets:  116
#       support                                        itemsets
# 0    0.010063                         (Feta Cheese Crumbles,)
# 1    0.010120                        (Organic Russet Potato,)
# 2    0.010199                        (Sparkling Lemon Water,)
# 3    0.010230                     (Organic Broccoli Florets,)
# 4    0.010547                            (Pure Irish Butter,)
# ..        ...                                             ...
# 101  0.011862    (Organic Baby Spinach, Organic Strawberries)
# 102  0.015668  (Organic Baby Spinach, Bag of Organic Bananas)
# 103  0.015987                  (Organic Baby Spinach, Banana)
# 104  0.017468                  (Organic Strawberries, Banana)
# 105  0.019170  (Organic Strawberries, Bag of Organic Bananas)
#
# [106 rows x 2 columns]
# Number of maximal itemsets:  106
#       support                                        itemsets
# 0    0.010063                         (Feta Cheese Crumbles,)
# 1    0.010120                        (Organic Russet Potato,)
# 2    0.010199                        (Sparkling Lemon Water,)
# 3    0.010230                     (Organic Broccoli Florets,)
# 4    0.010547                            (Pure Irish Butter,)
# ..        ...                                             ...
# 111  0.017468                  (Organic Strawberries, Banana)
# 112  0.019170  (Organic Strawberries, Bag of Organic Bananas)
# 113  0.082331                         (Organic Strawberries,)
# 114  0.118030                       (Bag of Organic Bananas,)
# 115  0.146993                                       (Banana,)
#
# [116 rows x 2 columns]
# Number of closed itemsets:  116
# Overlap between maximal and closed itemsets: support     86
# itemsets    86
# dtype: int64

# %%
# Calculate all rules -------------------------------------------------------
all_rules = association_rules(FI_eclat, metric="confidence",min_threshold=0)
print("Rules length: ", all_rules.shape[0])

# Sort all rules by lift in descending order
rules_sorted_by_lift = all_rules.sort_values(by='lift', ascending=False)
# Select the top 10 rules with the highest lift
top_10_rules = rules_sorted_by_lift.head(10)

display(Markdown('## 1. From your predefined support level generate all available itemsets and generate rules'))
display(Markdown('### Association Rules'))
display(all_rules)
display(Markdown('### Frequent Itemsets'))
display(FI_eclat)
display(Markdown('## 2. Identify a set of 10 relevant rules using the Highest Lift criterion'))
display(top_10_rules)

# Calculate rules for maximal and closed itemsets -------------------------------------------------------

# function to calculate the rules of a given itemset with support_only=True
# and setting the lift score where possible by using all_rules calculated earlier
def calculate_rules_and_get_highest_lift_rules(itemset, itemset_name = ""):
    rules = association_rules(itemset, metric="confidence",min_threshold=0, support_only=True)
    print(itemset_name + " Rules length: ", rules.shape[0])

    counter_both_rules = 0

    for index in rules.index:
        row = rules.iloc[index]
        row_all_rules = all_rules[(all_rules['antecedents'] == row['antecedents']) & (all_rules['consequents'] == row['consequents'])]
        if not row_all_rules.empty:
            counter_both_rules += 1
            lift = row_all_rules['lift']
            rules.at[index, 'lift'] = lift.values[0]

    print("Number of rules that exist in all rules and in " + itemset_name + " rules: ", counter_both_rules)
    return rules

# Display results
display(Markdown('## 3.'))

display(Markdown('### Maximal itemsets'))
# Get rules for maximal itemsets and calculate the lift where exist in all itemsets
maximal_rules = calculate_rules_and_get_highest_lift_rules(maximal_itemsets, "Maximal itemsets")
# Sort the rules by lift in descending order
maximal_rules_sorted_by_lift = maximal_rules.sort_values(by='lift', ascending=False)
display(Markdown('#### Identify all maximal itemsets'))
display(maximal_rules)
# Select the top 5 rules with the highest lift
display(Markdown('#### Maximal itemsets: Identify a set of 5 relevant rules using the Highest Lift criterion'))
display(maximal_rules_sorted_by_lift.head(5))

print("")

display(Markdown('### Closed itemsets'))
# Get rules for closed itemsets and calculate the lift where exist in all itemsets
closed_rules = calculate_rules_and_get_highest_lift_rules(closed_itemsets, "Closed itemsets")
# Sort the rules by lift in descending order
closed_rules_sorted_by_lift = closed_rules.sort_values(by='lift', ascending=False)
display(Markdown('#### Identify all closed itemsets'))
display(closed_rules)
# Select the top 5 rules with the highest lift
display(Markdown('#### Closed itemsets: Identify a set of 5 relevant rules using the Highest Lift criterion'))
display(closed_rules_sorted_by_lift.head(5))

rules_overlap = maximal_rules.isin(closed_rules)
print(f"Overlap between maximal and closed itemsets rules: {rules_overlap.sum()}")
# Out:
# Rules length:  28
# ## 1. From your predefined support level generate all available itemsets and generate rules
# ### Association Rules
#                  antecedents               consequents  antecedent support  \
# 0       (Organic Fuji Apple)                  (Banana)            0.027880
# 1                   (Banana)      (Organic Fuji Apple)            0.146993
# 2      (Organic Raspberries)    (Organic Strawberries)            0.042632
# 3     (Organic Strawberries)     (Organic Raspberries)            0.082331
# 4   (Bag of Organic Bananas)     (Organic Raspberries)            0.118030
# 5      (Organic Raspberries)  (Bag of Organic Bananas)            0.042632
# 6                   (Banana)            (Strawberries)            0.146993
# 7             (Strawberries)                  (Banana)            0.044466
# 8                   (Banana)             (Large Lemon)            0.146993
# 9              (Large Lemon)                  (Banana)            0.047485
# 10         (Organic Avocado)                  (Banana)            0.054999
# 11                  (Banana)         (Organic Avocado)            0.146993
# 12    (Organic Baby Spinach)    (Organic Hass Avocado)            0.075251
# 13    (Organic Hass Avocado)    (Organic Baby Spinach)            0.066436
# 14    (Organic Strawberries)    (Organic Hass Avocado)            0.082331
# 15    (Organic Hass Avocado)    (Organic Strawberries)            0.066436
# 16  (Bag of Organic Bananas)    (Organic Hass Avocado)            0.118030
# 17    (Organic Hass Avocado)  (Bag of Organic Bananas)            0.066436
# 18    (Organic Baby Spinach)    (Organic Strawberries)            0.075251
# 19    (Organic Strawberries)    (Organic Baby Spinach)            0.082331
# 20    (Organic Baby Spinach)  (Bag of Organic Bananas)            0.075251
# 21  (Bag of Organic Bananas)    (Organic Baby Spinach)            0.118030
# 22                  (Banana)    (Organic Baby Spinach)            0.146993
# 23    (Organic Baby Spinach)                  (Banana)            0.075251
# 24                  (Banana)    (Organic Strawberries)            0.146993
# 25    (Organic Strawberries)                  (Banana)            0.082331
# 26  (Bag of Organic Bananas)    (Organic Strawberries)            0.118030
# 27    (Organic Strawberries)  (Bag of Organic Bananas)            0.082331
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.146993  0.010558    0.378693  2.576259  0.006460    1.372923
# 1             0.027880  0.010558    0.071827  2.576259  0.006460    1.047348
# 2             0.082331  0.010533    0.247072  3.000973  0.007023    1.218801
# 3             0.042632  0.010533    0.127938  3.000973  0.007023    1.097821
# 4             0.042632  0.012599    0.106741  2.503775  0.007567    1.071770
# 5             0.118030  0.012599    0.295519  2.503775  0.007567    1.251944
# 6             0.044466  0.012825    0.087251  1.962229  0.006289    1.046876
# 7             0.146993  0.012825    0.288434  1.962229  0.006289    1.198775
# 8             0.047485  0.012716    0.086507  1.821783  0.005736    1.042717
# 9             0.146993  0.012716    0.267790  1.821783  0.005736    1.164975
# 10            0.146993  0.016609    0.301982  2.054395  0.008524    1.222042
# 11            0.054999  0.016609    0.112990  2.054395  0.008524    1.065378
# 12            0.066436  0.010856    0.144266  2.171499  0.005857    1.090951
# 13            0.075251  0.010856    0.163406  2.171499  0.005857    1.105375
# 14            0.066436  0.012689    0.154124  2.319880  0.007219    1.103665
# 15            0.082331  0.012689    0.190997  2.319880  0.007219    1.134322
# 16            0.066436  0.019391    0.164293  2.472945  0.011550    1.117095
# 17            0.118030  0.019391    0.291880  2.472945  0.011550    1.245511
# 18            0.082331  0.011862    0.157630  1.914594  0.005666    1.089390
# 19            0.075251  0.011862    0.144074  1.914594  0.005666    1.080408
# 20            0.118030  0.015668    0.208217  1.764107  0.006787    1.113904
# 21            0.075251  0.015668    0.132750  1.764107  0.006787    1.066301
# 22            0.075251  0.015987    0.108758  1.445272  0.004925    1.037596
# 23            0.146993  0.015987    0.212445  1.445272  0.004925    1.083108
# 24            0.082331  0.017468    0.118832  1.443353  0.005365    1.041424
# 25            0.146993  0.017468    0.212163  1.443353  0.005365    1.082720
# 26            0.082331  0.019170    0.162414  1.972702  0.009452    1.095612
# 27            0.118030  0.019170    0.232837  1.972702  0.009452    1.149652
#
#     zhangs_metric
# 0        0.629388
# 1        0.717275
# 2        0.696467
# 3        0.726596
# 4        0.680979
# 5        0.627348
# 6        0.574879
# 7        0.513195
# 8        0.528820
# 9        0.473575
# 10       0.543109
# 11       0.601682
# 12       0.583389
# 13       0.577881
# 14       0.619987
# 15       0.609431
# 16       0.675333
# 17       0.638011
# 18       0.516568
# 19       0.520554
# 20       0.468388
# 21       0.491106
# 22       0.361180
# 23       0.333159
# 24       0.360101
# 25       0.334727
# 26       0.559067
# 27       0.537319
# ### Frequent Itemsets
#       support                                        itemsets
# 0    0.010063                         (Feta Cheese Crumbles,)
# 1    0.010120                        (Organic Russet Potato,)
# 2    0.010199                        (Sparkling Lemon Water,)
# 3    0.010230                     (Organic Broccoli Florets,)
# 4    0.010547                            (Pure Irish Butter,)
# ..        ...                                             ...
# 111  0.017468                  (Organic Strawberries, Banana)
# 112  0.019170  (Organic Strawberries, Bag of Organic Bananas)
# 113  0.082331                         (Organic Strawberries,)
# 114  0.118030                       (Bag of Organic Bananas,)
# 115  0.146993                                       (Banana,)
#
# [116 rows x 2 columns]
# ## 2. Identify a set of 10 relevant rules using the Highest Lift criterion
#                  antecedents               consequents  antecedent support  \
# 2      (Organic Raspberries)    (Organic Strawberries)            0.042632
# 3     (Organic Strawberries)     (Organic Raspberries)            0.082331
# 0       (Organic Fuji Apple)                  (Banana)            0.027880
# 1                   (Banana)      (Organic Fuji Apple)            0.146993
# 4   (Bag of Organic Bananas)     (Organic Raspberries)            0.118030
# 5      (Organic Raspberries)  (Bag of Organic Bananas)            0.042632
# 16  (Bag of Organic Bananas)    (Organic Hass Avocado)            0.118030
# 17    (Organic Hass Avocado)  (Bag of Organic Bananas)            0.066436
# 15    (Organic Hass Avocado)    (Organic Strawberries)            0.066436
# 14    (Organic Strawberries)    (Organic Hass Avocado)            0.082331
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 2             0.082331  0.010533    0.247072  3.000973  0.007023    1.218801
# 3             0.042632  0.010533    0.127938  3.000973  0.007023    1.097821
# 0             0.146993  0.010558    0.378693  2.576259  0.006460    1.372923
# 1             0.027880  0.010558    0.071827  2.576259  0.006460    1.047348
# 4             0.042632  0.012599    0.106741  2.503775  0.007567    1.071770
# 5             0.118030  0.012599    0.295519  2.503775  0.007567    1.251944
# 16            0.066436  0.019391    0.164293  2.472945  0.011550    1.117095
# 17            0.118030  0.019391    0.291880  2.472945  0.011550    1.245511
# 15            0.082331  0.012689    0.190997  2.319880  0.007219    1.134322
# 14            0.066436  0.012689    0.154124  2.319880  0.007219    1.103665
#
#     zhangs_metric
# 2        0.696467
# 3        0.726596
# 0        0.629388
# 1        0.717275
# 4        0.680979
# 5        0.627348
# 16       0.675333
# 17       0.638011
# 15       0.609431
# 14       0.619987
# ## 3.
# ### Maximal itemsets
# Maximal itemsets Rules length:  28
# Number of rules that exist in all rules and in Maximal itemsets rules:  28
# #### Identify all maximal itemsets
#                  antecedents               consequents  antecedent support  \
# 0       (Organic Fuji Apple)                  (Banana)                 NaN
# 1                   (Banana)      (Organic Fuji Apple)                 NaN
# 2      (Organic Raspberries)    (Organic Strawberries)                 NaN
# 3     (Organic Strawberries)     (Organic Raspberries)                 NaN
# 4   (Bag of Organic Bananas)     (Organic Raspberries)                 NaN
# 5      (Organic Raspberries)  (Bag of Organic Bananas)                 NaN
# 6                   (Banana)            (Strawberries)                 NaN
# 7             (Strawberries)                  (Banana)                 NaN
# 8                   (Banana)             (Large Lemon)                 NaN
# 9              (Large Lemon)                  (Banana)                 NaN
# 10         (Organic Avocado)                  (Banana)                 NaN
# 11                  (Banana)         (Organic Avocado)                 NaN
# 12    (Organic Baby Spinach)    (Organic Hass Avocado)                 NaN
# 13    (Organic Hass Avocado)    (Organic Baby Spinach)                 NaN
# 14    (Organic Strawberries)    (Organic Hass Avocado)                 NaN
# 15    (Organic Hass Avocado)    (Organic Strawberries)                 NaN
# 16  (Bag of Organic Bananas)    (Organic Hass Avocado)                 NaN
# 17    (Organic Hass Avocado)  (Bag of Organic Bananas)                 NaN
# 18    (Organic Baby Spinach)    (Organic Strawberries)                 NaN
# 19    (Organic Strawberries)    (Organic Baby Spinach)                 NaN
# 20    (Organic Baby Spinach)  (Bag of Organic Bananas)                 NaN
# 21  (Bag of Organic Bananas)    (Organic Baby Spinach)                 NaN
# 22                  (Banana)    (Organic Baby Spinach)                 NaN
# 23    (Organic Baby Spinach)                  (Banana)                 NaN
# 24                  (Banana)    (Organic Strawberries)                 NaN
# 25    (Organic Strawberries)                  (Banana)                 NaN
# 26  (Bag of Organic Bananas)    (Organic Strawberries)                 NaN
# 27    (Organic Strawberries)  (Bag of Organic Bananas)                 NaN
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0                  NaN  0.010558         NaN  2.576259       NaN         NaN
# 1                  NaN  0.010558         NaN  2.576259       NaN         NaN
# 2                  NaN  0.010533         NaN  3.000973       NaN         NaN
# 3                  NaN  0.010533         NaN  3.000973       NaN         NaN
# 4                  NaN  0.012599         NaN  2.503775       NaN         NaN
# 5                  NaN  0.012599         NaN  2.503775       NaN         NaN
# 6                  NaN  0.012825         NaN  1.962229       NaN         NaN
# 7                  NaN  0.012825         NaN  1.962229       NaN         NaN
# 8                  NaN  0.012716         NaN  1.821783       NaN         NaN
# 9                  NaN  0.012716         NaN  1.821783       NaN         NaN
# 10                 NaN  0.016609         NaN  2.054395       NaN         NaN
# 11                 NaN  0.016609         NaN  2.054395       NaN         NaN
# 12                 NaN  0.010856         NaN  2.171499       NaN         NaN
# 13                 NaN  0.010856         NaN  2.171499       NaN         NaN
# 14                 NaN  0.012689         NaN  2.319880       NaN         NaN
# 15                 NaN  0.012689         NaN  2.319880       NaN         NaN
# 16                 NaN  0.019391         NaN  2.472945       NaN         NaN
# 17                 NaN  0.019391         NaN  2.472945       NaN         NaN
# 18                 NaN  0.011862         NaN  1.914594       NaN         NaN
# 19                 NaN  0.011862         NaN  1.914594       NaN         NaN
# 20                 NaN  0.015668         NaN  1.764107       NaN         NaN
# 21                 NaN  0.015668         NaN  1.764107       NaN         NaN
# 22                 NaN  0.015987         NaN  1.445272       NaN         NaN
# 23                 NaN  0.015987         NaN  1.445272       NaN         NaN
# 24                 NaN  0.017468         NaN  1.443353       NaN         NaN
# 25                 NaN  0.017468         NaN  1.443353       NaN         NaN
# 26                 NaN  0.019170         NaN  1.972702       NaN         NaN
# 27                 NaN  0.019170         NaN  1.972702       NaN         NaN
#
#     zhangs_metric
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# #### Maximal itemsets: Identify a set of 5 relevant rules using the Highest Lift criterion
#                 antecedents             consequents  antecedent support  \
# 2     (Organic Raspberries)  (Organic Strawberries)                 NaN
# 3    (Organic Strawberries)   (Organic Raspberries)                 NaN
# 0      (Organic Fuji Apple)                (Banana)                 NaN
# 1                  (Banana)    (Organic Fuji Apple)                 NaN
# 4  (Bag of Organic Bananas)   (Organic Raspberries)                 NaN
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 2                 NaN  0.010533         NaN  3.000973       NaN         NaN
# 3                 NaN  0.010533         NaN  3.000973       NaN         NaN
# 0                 NaN  0.010558         NaN  2.576259       NaN         NaN
# 1                 NaN  0.010558         NaN  2.576259       NaN         NaN
# 4                 NaN  0.012599         NaN  2.503775       NaN         NaN
#
#    zhangs_metric
# 2            NaN
# 3            NaN
# 0            NaN
# 1            NaN
# 4            NaN
# ### Closed itemsets
# Closed itemsets Rules length:  28
# Number of rules that exist in all rules and in Closed itemsets rules:  28
# #### Identify all closed itemsets
#                  antecedents               consequents  antecedent support  \
# 0       (Organic Fuji Apple)                  (Banana)                 NaN
# 1                   (Banana)      (Organic Fuji Apple)                 NaN
# 2      (Organic Raspberries)    (Organic Strawberries)                 NaN
# 3     (Organic Strawberries)     (Organic Raspberries)                 NaN
# 4   (Bag of Organic Bananas)     (Organic Raspberries)                 NaN
# 5      (Organic Raspberries)  (Bag of Organic Bananas)                 NaN
# 6                   (Banana)            (Strawberries)                 NaN
# 7             (Strawberries)                  (Banana)                 NaN
# 8                   (Banana)             (Large Lemon)                 NaN
# 9              (Large Lemon)                  (Banana)                 NaN
# 10         (Organic Avocado)                  (Banana)                 NaN
# 11                  (Banana)         (Organic Avocado)                 NaN
# 12    (Organic Baby Spinach)    (Organic Hass Avocado)                 NaN
# 13    (Organic Hass Avocado)    (Organic Baby Spinach)                 NaN
# 14    (Organic Strawberries)    (Organic Hass Avocado)                 NaN
# 15    (Organic Hass Avocado)    (Organic Strawberries)                 NaN
# 16  (Bag of Organic Bananas)    (Organic Hass Avocado)                 NaN
# 17    (Organic Hass Avocado)  (Bag of Organic Bananas)                 NaN
# 18    (Organic Baby Spinach)    (Organic Strawberries)                 NaN
# 19    (Organic Strawberries)    (Organic Baby Spinach)                 NaN
# 20    (Organic Baby Spinach)  (Bag of Organic Bananas)                 NaN
# 21  (Bag of Organic Bananas)    (Organic Baby Spinach)                 NaN
# 22                  (Banana)    (Organic Baby Spinach)                 NaN
# 23    (Organic Baby Spinach)                  (Banana)                 NaN
# 24                  (Banana)    (Organic Strawberries)                 NaN
# 25    (Organic Strawberries)                  (Banana)                 NaN
# 26  (Bag of Organic Bananas)    (Organic Strawberries)                 NaN
# 27    (Organic Strawberries)  (Bag of Organic Bananas)                 NaN
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0                  NaN  0.010558         NaN  2.576259       NaN         NaN
# 1                  NaN  0.010558         NaN  2.576259       NaN         NaN
# 2                  NaN  0.010533         NaN  3.000973       NaN         NaN
# 3                  NaN  0.010533         NaN  3.000973       NaN         NaN
# 4                  NaN  0.012599         NaN  2.503775       NaN         NaN
# 5                  NaN  0.012599         NaN  2.503775       NaN         NaN
# 6                  NaN  0.012825         NaN  1.962229       NaN         NaN
# 7                  NaN  0.012825         NaN  1.962229       NaN         NaN
# 8                  NaN  0.012716         NaN  1.821783       NaN         NaN
# 9                  NaN  0.012716         NaN  1.821783       NaN         NaN
# 10                 NaN  0.016609         NaN  2.054395       NaN         NaN
# 11                 NaN  0.016609         NaN  2.054395       NaN         NaN
# 12                 NaN  0.010856         NaN  2.171499       NaN         NaN
# 13                 NaN  0.010856         NaN  2.171499       NaN         NaN
# 14                 NaN  0.012689         NaN  2.319880       NaN         NaN
# 15                 NaN  0.012689         NaN  2.319880       NaN         NaN
# 16                 NaN  0.019391         NaN  2.472945       NaN         NaN
# 17                 NaN  0.019391         NaN  2.472945       NaN         NaN
# 18                 NaN  0.011862         NaN  1.914594       NaN         NaN
# 19                 NaN  0.011862         NaN  1.914594       NaN         NaN
# 20                 NaN  0.015668         NaN  1.764107       NaN         NaN
# 21                 NaN  0.015668         NaN  1.764107       NaN         NaN
# 22                 NaN  0.015987         NaN  1.445272       NaN         NaN
# 23                 NaN  0.015987         NaN  1.445272       NaN         NaN
# 24                 NaN  0.017468         NaN  1.443353       NaN         NaN
# 25                 NaN  0.017468         NaN  1.443353       NaN         NaN
# 26                 NaN  0.019170         NaN  1.972702       NaN         NaN
# 27                 NaN  0.019170         NaN  1.972702       NaN         NaN
#
#     zhangs_metric
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# #### Closed itemsets: Identify a set of 5 relevant rules using the Highest Lift criterion
#                 antecedents             consequents  antecedent support  \
# 2     (Organic Raspberries)  (Organic Strawberries)                 NaN
# 3    (Organic Strawberries)   (Organic Raspberries)                 NaN
# 0      (Organic Fuji Apple)                (Banana)                 NaN
# 1                  (Banana)    (Organic Fuji Apple)                 NaN
# 4  (Bag of Organic Bananas)   (Organic Raspberries)                 NaN
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 2                 NaN  0.010533         NaN  3.000973       NaN         NaN
# 3                 NaN  0.010533         NaN  3.000973       NaN         NaN
# 0                 NaN  0.010558         NaN  2.576259       NaN         NaN
# 1                 NaN  0.010558         NaN  2.576259       NaN         NaN
# 4                 NaN  0.012599         NaN  2.503775       NaN         NaN
#
#    zhangs_metric
# 2            NaN
# 3            NaN
# 0            NaN
# 1            NaN
# 4            NaN
# Overlap between maximal and closed itemsets rules: antecedents           28
# consequents           28
# antecedent support     0
# consequent support     0
# support               28
# confidence             0
# lift                  28
# leverage               0
# conviction             0
# zhangs_metric          0
# dtype: int64

# %% [markdown]
# ### Your short analysis here
#
# Using the association_rules from the mlxtend library all rules for frequent itemsets can be generated. To achieve this we first use the FP-Growth algorthm as it outputs the data in a easier format than ECLAT to then input it in the association_rules function of mlxtend. To generate all rules we set the threshold to 0. This output all rules with their associated metric values like confidence, lift, conviction.
#
# We use the **Highest Lift Criterion** metric to filter for the ten most relevant rules. The lift metric tells us how likely an item (or a set of items), also called consequents, is/are to be purchased when item (set of items), called antecedents, is/are purchased. Differet to the confidence metric the lift also takes into account **how popular the consequents items are**. A lift score higher than 1 means that the consequents item(s) are likely to be bought if antecedents item(s) are bought.
#
# Looking at the 10 rules with the highest lift score, we can see that it is very likely, that Organic Strawberries are bought if Organic Raspberries are also bought. Interestingly this dependence is interchangeable as we can see by looking at the top two rules.
#
# **Calculating maximal and closed itemsets:**
#
# Using ECLAT with the same support threshold as before (0.01) we can find the maximal and closed itemsets using the method pyeclat and setting the target parameter to "c" for closed and "m" for maximal itemsets. Looking at the results it is interesting to note that for closed itemsets in total 116 itemsets were found which is the same number as all itemsets calculated by ECLAT. For the maximal itemsets we get a length of 106 entries. It is logical that the number of the maximal itemsets is lower than the number of the closed itemsets that were found as the set of maximal itemsets are a subset of the set of closed itemsets. If we look at the overlapping rows in the two itemsets we get a total of 86 overlapping itemsets.
#
# When calculating the rules we initially only can calculate the support metric for each rule, as maximal and closed itemsets are a subset of all itemsets and therefore don't include all itemsets that are necessary to calculate metrics like lift. To solve this issue we can iterate over the rules calculated for the closed and maximal itemset and if these rules also exist in the rules from all itemsets, meaning we compare the columns "antecedents" and "consequents" of the two resulting rule sets, we can use the calculated lift value in all rules and set it for this entry in the according itemset.
#
# Interestingly not all entries in the resulting closed and maximal rules also exist in the rules for all itemsets. The reason for this is because the association rules derived from maximal and closed itemsets can only involve the items within those itemsets, and no subsets of those itemsets, whereas the rules generated from all frequent itemsets can involve any combination of items from all itemsets, including those that are part of maximal itemsets. Therefore the lift metric score can only be calculated for the rules that also exist in the rules generated from all itemsets. Lastly we realize that the generated rules for the closed and maximal itemsets are exactly the same.
